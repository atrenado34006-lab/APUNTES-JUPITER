// %% [markdown]
// 1. Inicio (Principal)
//    ↓
// 2. Declarar variable entera "i"
//    ↓
// 3. ¿i está entre 20 y 30?
//    ├── NO → Fin del programa (Hecho)
//    ↓
//    └── SÍ → Mostrar valor de "i" (Salida i)
//             ↓
//             Volver al paso 3 (Siguiente)

// %% [markdown]
// ![image.png](attachment:4f1499de-829b-49e5-a67e-3c4ac3b29582.png)

// %% [markdown]
// ![image.png](attachment:43c31fc9-2027-4111-bd82-dfd5c79b5bd0.png)
